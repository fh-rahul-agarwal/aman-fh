# %% [markdown]
# ### File Imports

# %%
#Parse XML
# from data_source.parse_xml.parseXML import *

# Sleep Pillar

from processing.pillars.sleep.dataStream.s_typeSleep import *

from processing.pillars.sleep.dataAggregate.s_typeSleep_aggFunc import *
from processing.pillars.sleep.dataAggregate.s_effectiveness_aggFunc import *
from processing.pillars.sleep.dataAggregate.s_efficiency_aggFunc import *
from processing.pillars.sleep.dataAggregate.s_waso_aggFunc import *
from processing.pillars.sleep.dataAggregate.s_onsetLatency_aggFunc import *
# Out:
# c:\Users\amank\Downloads\Fithack\Optimization\processing\pillars\sleep\dataStream\s_typeSleep.py:93: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   records_df = pd.read_csv(r"C:\Users\amank\Downloads\Fithack\Optimization\local_files\records_df.csv")
#                                 userName     valueGeneratedAt  \
# 0   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:11
# 1   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:11
# 2   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:11
# 3   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:11
# 4   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:11
# ..                                   ...                  ...
# 63  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:11
# 64  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:11
# 65  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:11
# ...

# %% [markdown]
# - To access minus one day data use this argument structure:
# **process_minus_one_data(df, start date, Class Name)**
# - To access whole table data use this argument structure:
# **ClassName(df).process_data('startdate')**

# %%
# file_path = 'C:/Users/DELL/Desktop/ft_data_codebase/local_files/export.xml'
# parser = parseXML(file_path)

# records_df = parser.records_data()
# workouts_df = parser.workouts_data()
records_df = pd.read_csv(r"C:\Users\amank\Downloads\Fithack\Optimization\local_files\records_df.csv")
workouts_df = pd.read_csv(r"C:\Users\amank\Downloads\Fithack\Optimization\local_files\workouts_df.csv")
# Out:
# C:\Users\amank\AppData\Local\Temp\ipykernel_43360\3985036706.py:6: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   records_df = pd.read_csv(r"C:\Users\amank\Downloads\Fithack\Optimization\local_files\records_df.csv")

# %%
user_name = "5cbdc5c5-2793-452b-a95d-0dbd3a8719ce"
start_date = '2024-09-19'
days_offset = 2
offset_sign = '-'

# Add the new column to both DataFrames
records_df['userName'] = user_name

# Reorder the columns to position 'userName' as the first column
records_columns = ['userName'] + [col for col in records_df.columns if col != 'userName']

records_df = records_df[records_columns]

# %%
sleep_data_processor = SSleepTypeAgg(records_df, start_date, days_offset, offset_sign)
sleepTypeAgg_df = sleep_data_processor.process()
sleepTypeAgg_df
# Out:
# c:\Users\amank\Downloads\Fithack\Optimization\processing\pillars\sleep\dataStream\s_typeSleep.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['dateSorting'] = pd.to_datetime(result_df['creationDate'], errors='coerce').dt.date
#                                 userName     valueGeneratedAt       s_name  \
# 0   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:16  S_SleepType
# 1   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:16  S_SleepType
# 2   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:16  S_SleepType
# 3   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:16  S_SleepType
# 4   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:16  S_SleepType
# ...

# %%
effectiveness_processor = SEffectivenessAgg(records_df, start_date, days_offset, offset_sign)
effectiveness_df = effectiveness_processor.process()
effectiveness_df
# Out:
# c:\Users\amank\Downloads\Fithack\Optimization\processing\pillars\sleep\dataStream\s_typeSleep.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['dateSorting'] = pd.to_datetime(result_df['creationDate'], errors='coerce').dt.date
# c:\Users\amank\Downloads\Fithack\Optimization\processing\pillars\sleep\dataStream\s_typeSleep.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['dateSorting'] = pd.to_datetime(result_df['creationDate'], errors='coerce').dt.date
# ...

# %%
onset_latency_processor = SOnsetLatencyAgg(records_df, start_date, days_offset, offset_sign)
onset_latency_df = onset_latency_processor.process()
onset_latency_df
# Out:
# c:\Users\amank\Downloads\Fithack\Optimization\processing\pillars\sleep\dataStream\s_typeSleep.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['dateSorting'] = pd.to_datetime(result_df['creationDate'], errors='coerce').dt.date
#                                userName     valueGeneratedAt          s_name  \
# 0  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:17  S_OnsetLatency
# 1  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:17  S_OnsetLatency
# 2  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:17  S_OnsetLatency
#
#          date                                   type      unit  \
# 0  2024-09-17  HKCategoryTypeIdentifierSleepAnalysis       min
# ...

# %%
sleep_data_processor = SEfficiencyAgg(records_df, start_date, days_offset, offset_sign)
efficiency_df = sleep_data_processor.process()
efficiency_df
# Out:
# c:\Users\amank\Downloads\Fithack\Optimization\processing\pillars\sleep\dataStream\s_typeSleep.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['dateSorting'] = pd.to_datetime(result_df['creationDate'], errors='coerce').dt.date
#                                userName     valueGeneratedAt        s_name  \
# 0  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:17  S_Efficiency
# 1  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:17  S_Efficiency
# 2  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:17  S_Efficiency
#
#          date                                   type unit        valueType  \
# 0  2024-09-19  HKCategoryTypeIdentifierSleepAnalysis    %  SleepEfficiency
# ...

# %%
sleep_data_processor = SWASOAgg(records_df, start_date, days_offset, offset_sign)
waso_df = sleep_data_processor.process()
waso_df
# Out:
# c:\Users\amank\Downloads\Fithack\Optimization\processing\pillars\sleep\dataStream\s_typeSleep.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['dateSorting'] = pd.to_datetime(result_df['creationDate'], errors='coerce').dt.date
#                                userName     valueGeneratedAt  s_name  \
# 0  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:17  S_WASO
# 1  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:17  S_WASO
# 2  5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:17  S_WASO
#
#          date                                   type unit  \
# 0  2024-09-19  HKCategoryTypeIdentifierSleepAnalysis    %
# 1  2024-09-18  HKCategoryTypeIdentifierSleepAnalysis    %
# ...

# %%
sleep_data_processor = SSleepType(records_df, start_date, days_offset, offset_sign)
sleepTypeStream_df = sleep_data_processor.process()
sleepTypeStream_df
# Out:
# c:\Users\amank\Downloads\Fithack\Optimization\processing\pillars\sleep\dataStream\s_typeSleep.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['dateSorting'] = pd.to_datetime(result_df['creationDate'], errors='coerce').dt.date
#                                 userName     valueGeneratedAt  \
# 0   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:18
# 1   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:18
# 2   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:18
# 3   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:18
# 4   5cbdc5c5-2793-452b-a95d-0dbd3a8719ce  2024-10-15 22:02:18
# ..                                   ...                  ...
# ...

# %%
"""file_path = 'C:/Users/DELL/Desktop/ft_data_codebase/local_files/sleep_extract.xlsx'

# Save to Excel with sheet name
with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
    sleepTypeStream_df.to_excel(writer, sheet_name='S_SleepType_Stream', index=False)
    sleepTypeAgg_df.to_excel(writer, sheet_name='S_SleepType_Agg', index=False)
    efficiency_df.to_excel(writer, sheet_name='S_Efficiency_Agg', index=False)
    onset_latency_df.to_excel(writer, sheet_name='S_OnsetLatency_Agg', index=False)
    waso_df.to_excel(writer, sheet_name='S_WASO_Agg', index=False)
    effectiveness_df.to_excel(writer, sheet_name='S_Effectiveness_Agg', index=False)"""
# Out:
# "file_path = 'C:/Users/DELL/Desktop/ft_data_codebase/local_files/sleep_extract.xlsx'\n\n# Save to Excel with sheet name\nwith pd.ExcelWriter(file_path, engine='openpyxl') as writer:\n    sleepTypeStream_df.to_excel(writer, sheet_name='S_SleepType_Stream', index=False)\n    sleepTypeAgg_df.to_excel(writer, sheet_name='S_SleepType_Agg', index=False)\n    efficiency_df.to_excel(writer, sheet_name='S_Efficiency_Agg', index=False)\n    onset_latency_df.to_excel(writer, sheet_name='S_OnsetLatency_Agg', index=False)\n    waso_df.to_excel(writer, sheet_name='S_WASO_Agg', index=False)\n    effectiveness_df.to_excel(writer, sheet_name='S_Effectiveness_Agg', index=False)"
